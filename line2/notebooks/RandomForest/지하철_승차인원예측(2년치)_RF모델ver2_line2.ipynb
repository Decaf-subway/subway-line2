# %% [markdown]
# # 1. 필요한 라이브러리 불러오기
#
# 데이터 분석과 머신러닝 모델 학습에 필요한 라이브러리를 불러옵니다.
#
# - pandas : 데이터 처리
# - numpy : 수치 계산
# - matplotlib : 데이터 시각화
# - sklearn : 머신러닝 모델 및 평가
# - optuna : 하이퍼파라미터 최적화

# %%
# !apt-get update -qq
# !apt-get install -qq fonts-nanum
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 118242 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
# !fc-list | grep Nanum
# Out:
# /usr/share/fonts/truetype/nanum/NanumSquareRoundB.ttf: NanumSquareRound,나눔스퀘어라운드,NanumSquareRound Bold,나눔스퀘어라운드 Bold:style=Bold,Regular
# /usr/share/fonts/truetype/nanum/NanumGothicCodingBold.ttf: NanumGothicCoding,나눔고딕코딩:style=Bold
# /usr/share/fonts/truetype/nanum/NanumSquareRoundR.ttf: NanumSquareRound,나눔스퀘어라운드,NanumSquareRound Regular,나눔스퀘어라운드 Regular:style=Regular
# /usr/share/fonts/truetype/nanum/NanumSquareB.ttf: NanumSquare,나눔스퀘어,NanumSquare Bold,나눔스퀘어 Bold:style=Bold
# /usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf: NanumBarunGothic,나눔바른고딕:style=Regular
# /usr/share/fonts/truetype/nanum/NanumGothic.ttf: NanumGothic,나눔고딕:style=Regular
# /usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf: NanumGothicCoding,나눔고딕코딩:style=Regular
# /usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf: NanumBarunGothic,나눔바른고딕:style=Bold
# /usr/share/fonts/truetype/nanum/NanumGothicBold.ttf: NanumGothic,나눔고딕:style=Bold
# /usr/share/fonts/truetype/nanum/NanumSquareR.ttf: NanumSquare,나눔스퀘어:style=Regular
# /usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf: NanumMyeongjo,나눔명조:style=Regular
# /usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf: NanumMyeongjo,나눔명조:style=Bold

# %%
# !pip install -q optuna

import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.model_selection import (
    train_test_split,
    cross_val_score
)

from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

import optuna

np.random.seed(42)

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.6/425.6 kB 9.2 MB/s eta 0:00:00

# %% [markdown]
# # 2. 전처리 완료 데이터 불러오기

# %%
df = pd.read_csv(
    'final_dataset_230101-241231.csv',
    encoding='utf-8-sig'
)

print('데이터 크기 :', df.shape)

df.head()

df.info()

print(
    df.memory_usage(deep=True).sum() / 1024**2,
    'MB'
)
# Out:
# 데이터 크기 : (731000, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731000 entries, 0 to 730999
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   날짜      731000 non-null  object
#  1   역명      731000 non-null  object
#  2   호선      731000 non-null  object
#  3   승차인원    731000 non-null  int64
#  4   시간      731000 non-null  int64
#  5   하차인원    731000 non-null  int64
#  6   요일      731000 non-null  int64
#  7   월       731000 non-null  int64
#  8   공휴일여부   731000 non-null  int64
#  9   기온      731000 non-null  float64
#  10  강수량     731000 non-null  float64
#  11  적설      731000 non-null  float64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 66.9+ MB
# 193.91545486450195 MB

# %% [markdown]
# # 3. 데이터 기본 정보 확인
#
# 데이터의:
# - 컬럼 정보
# - 데이터 타입
# - 결측치 여부

# %%
df.info()

print()

print('결측치 개수')

print(df.isnull().sum())

print()

print('중복 데이터 개수 :')

print(df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731000 entries, 0 to 730999
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   날짜      731000 non-null  object
#  1   역명      731000 non-null  object
#  2   호선      731000 non-null  object
#  3   승차인원    731000 non-null  int64
#  4   시간      731000 non-null  int64
#  5   하차인원    731000 non-null  int64
#  6   요일      731000 non-null  int64
#  7   월       731000 non-null  int64
#  8   공휴일여부   731000 non-null  int64
#  9   기온      731000 non-null  float64
#  10  강수량     731000 non-null  float64
#  11  적설      731000 non-null  float64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 66.9+ MB
#
# 결측치 개수
# 날짜       0
# 역명       0
# 호선       0
# 승차인원     0
# 시간       0
# 하차인원     0
# 요일       0
# 월        0
# 공휴일여부    0
# 기온       0
# 강수량      0
# 적설       0
# dtype: int64
#
# 중복 데이터 개수 :
# 0

# %% [markdown]
# # 4. Feature / Target 분리
#
# 머신러닝 입력 데이터(X)와 예측 대상(y)을 분리
#
# - X : 모델이 학습에 사용할 feature
# - y : 모델이 예측할 target

# %%
X = df[['역명', '시간', '요일', '월',
        '공휴일여부', '기온', '강수량', '적설']]

y = df['승차인원']

print(X.shape)

print(y.shape)
# Out:
# (731000, 8)
# (731000,)

# %% [markdown]
# # 5. One-Hot Encoding
#
# 문자형 데이터(역명)를 숫자 형태로 변환합니다.
#
# RandomForest 모델은 문자열을 직접 학습할 수 없기 때문에
# One-Hot Encoding을 사용합니다.

# %%
X_encoded = pd.get_dummies(
    X,
    columns=['역명']
)

print(X_encoded.shape)

X_encoded.head()
# Out:
# (731000, 57)
#    시간  요일  월  공휴일여부   기온  강수량   적설  역명_강남  역명_강변(동서울터미널)  역명_건대입구  ...  \
# 0   5   6  1      1  0.8  0.0  0.0  False          False    False  ...
# 1   5   6  1      1  0.8  0.0  0.0  False          False    False  ...
# 2   5   6  1      1  0.8  0.0  0.0  False          False    False  ...
# 3   5   6  1      1  0.8  0.0  0.0  False          False    False  ...
# 4   5   6  1      1  0.8  0.0  0.0  False          False    False  ...
#
#    역명_을지로입구  역명_이대  역명_잠실(송파구청)  역명_잠실나루  역명_잠실새내  역명_종합운동장  역명_충정로(경기대입구)  \
# 0     False  False        False    False    False     False          False
# 1      True  False        False    False    False     False          False
# 2     False  False        False    False    False     False          False
# 3     False  False        False    False    False     False          False
# 4     False  False        False    False    False     False          False
#
#    역명_한양대  역명_합정  역명_홍대입구
# 0   False  False    False
# 1   False  False    False
# 2   False  False    False
# 3   False  False    False
# 4   False  False    False
#
# [5 rows x 57 columns]

# %%
print('X 결측치 개수 :')

print(X_encoded.isnull().sum().sum())

print()

print('y 결측치 개수 :')

print(y.isnull().sum())

print()

print('X shape :')

print(X_encoded.shape)

print()

print('y shape :')

print(y.shape)
# Out:
# X 결측치 개수 :
# 0
#
# y 결측치 개수 :
# 0
#
# X shape :
# (731000, 57)
#
# y shape :
# (731000,)

# %% [markdown]
# # 6. 학습용 / 테스트용 데이터 분리
#
# 데이터를:
# - 학습용 데이터
# - 테스트용 데이터
#
# 로 분리
#
# - 학습 데이터 : 모델 학습에 사용
# - 테스트 데이터 : 최종 성능 평가에 사용

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded,
    y,
    test_size=0.2,
    random_state=42
)

print('X_train shape :', X_train.shape)

print('X_test shape :', X_test.shape)

print()

print('y_train shape :', y_train.shape)

print('y_test shape :', y_test.shape)

print()

print(
    'Train 비율 :',
    len(X_train) / len(X_encoded)
)

print(
    'Test 비율 :',
    len(X_test) / len(X_encoded)
)
# Out:
# X_train shape : (584800, 57)
# X_test shape : (146200, 57)
#
# y_train shape : (584800,)
# y_test shape : (146200,)
#
# Train 비율 : 0.8
# Test 비율 : 0.2

# %% [markdown]
# # 7. Optuna를 이용한 하이퍼파라미터 최적화
#
# Cross Validation을 사용하여:
# - X_train 내부에서만 성능 평가
# - 테스트 데이터 정보 누출 방지
# - 모델 신뢰성 향상

# %%
def objective(trial):

    n_estimators = trial.suggest_int(
        'n_estimators',
        50,
        100
    )

    max_depth = trial.suggest_int(
        'max_depth',
        25,
        30
    )

    min_samples_split = trial.suggest_int(
        'min_samples_split',
        2,
        10
    )

    min_samples_leaf = trial.suggest_int(
        'min_samples_leaf',
        1,
        5
    )

    model = RandomForestRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        random_state=42,
        n_jobs=-1
    )

    score = cross_val_score(
        model,
        X_train,
        y_train,
        cv=3,
        scoring='r2'
    ).mean()

    return score


study = optuna.create_study(
    direction='maximize'
)

study.optimize(
    objective,
    n_trials=15
)
# Out:
# [I 2026-05-29 08:31:01,172] A new study created in memory with name: no-name-b048bdef-fcde-4bd4-8440-379cb0288c7c
# [I 2026-05-29 08:32:55,615] Trial 0 finished with value: 0.9557605051292152 and parameters: {'n_estimators': 65, 'max_depth': 30, 'min_samples_split': 8, 'min_samples_leaf': 5}. Best is trial 0 with value: 0.9557605051292152.
# [I 2026-05-29 08:35:00,517] Trial 1 finished with value: 0.9365476439061191 and parameters: {'n_estimators': 77, 'max_depth': 26, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.9557605051292152.
# [I 2026-05-29 08:37:50,401] Trial 2 finished with value: 0.9470459847467033 and parameters: {'n_estimators': 100, 'max_depth': 28, 'min_samples_split': 7, 'min_samples_leaf': 5}. Best is trial 0 with value: 0.9557605051292152.
# [I 2026-05-29 08:39:41,203] Trial 3 finished with value: 0.9413936300344069 and parameters: {'n_estimators': 66, 'max_depth': 27, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.9557605051292152.
# [I 2026-05-29 08:42:05,917] Trial 4 finished with value: 0.9367528693190351 and parameters: {'n_estimators': 89, 'max_depth': 26, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.9557605051292152.
# [I 2026-05-29 08:44:04,389] Trial 5 finished with value: 0.9471480648035575 and parameters: {'n_estimators': 70, 'max_depth': 28, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.9557605051292152.
# [I 2026-05-29 08:46:05,629] Trial 6 finished with value: 0.9471919736794341 and parameters: {'n_estimators': 72, 'max_depth': 28, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.9557605051292152.
# [I 2026-05-29 08:47:47,929] Trial 7 finished with value: 0.9516862197311369 and parameters: {'n_estimators': 59, 'max_depth': 29, 'min_samples_split': 9, 'min_samples_leaf': 5}. Best is trial 0 with value: 0.9557605051292152.
# [I 2026-05-29 08:49:21,008] Trial 8 finished with value: 0.9471426601250023 and parameters: {'n_estimators': 54, 'max_depth': 28, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.9557605051292152.
# [I 2026-05-29 08:51:47,368] Trial 9 finished with value: 0.9559922198452675 and parameters: {'n_estimators': 82, 'max_depth': 30, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 9 with value: 0.9559922198452675.
# [I 2026-05-29 08:54:16,673] Trial 10 finished with value: 0.955721514552538 and parameters: {'n_estimators': 83, 'max_depth': 30, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 9 with value: 0.9559922198452675.
# [I 2026-05-29 08:56:52,564] Trial 11 finished with value: 0.955943968448933 and parameters: {'n_estimators': 89, 'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 9 with value: 0.9559922198452675.
# [I 2026-05-29 08:59:32,797] Trial 12 finished with value: 0.9560516813327357 and parameters: {'n_estimators': 92, 'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 12 with value: 0.9560516813327357.
# [I 2026-05-29 09:02:23,927] Trial 13 finished with value: 0.9520323442624136 and parameters: {'n_estimators': 98, 'max_depth': 29, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 12 with value: 0.9560516813327357.
# [I 2026-05-29 09:04:48,664] Trial 14 finished with value: 0.9316864877287943 and parameters: {'n_estimators': 91, 'max_depth': 25, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 12 with value: 0.9560516813327357.

# %% [markdown]
# # 8. 최적의 하이퍼파라미터로 최종 모델 생성
#
# Optuna가 찾은 최적의 하이퍼파라미터를 사용하여
# 최종 RandomForest 모델을 생성

# %%
best_params = study.best_params

print('Best Parameters :')

print(best_params)

print()

print('Best CV Score :')

print(study.best_value)

model = RandomForestRegressor(
    **best_params,
    random_state=42,
    n_jobs=-1
)
# Out:
# Best Parameters :
# {'n_estimators': 92, 'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 3}
#
# Best CV Score :
# 0.9560516813327357

# %% [markdown]
# # 9. 모델 학습
#
# 최종 RandomForest 모델을 학습

# %%
import time

start = time.time()

model.fit(
    X_train,
    y_train
)

end = time.time()

print('모델 학습 완료')

print()

print(
    '학습 시간 :',
    round(end - start, 2),
    '초'
)
# Out:
# 모델 학습 완료
#
# 학습 시간 : 90.37 초

# %% [markdown]
# # 10. 예측 수행
#
# 테스트 데이터를 이용하여 예측

# %%
# 이 셀은 모델만 불러와서 예측해보기 위한 코드이므로 학습까지 포함해서 순서대로 실행시에는 실행시키지 말 것
import joblib

# 모델 불러오기
model = joblib.load(
    'randomforest_boarding_model.pkl'
)

print("모델 로드 완료")
# Out:
# 모델 로드 완료

# %%
y_pred = model.predict(X_test)

print('예측 완료')

print()

print(y_pred[:5])

print()

result_df = pd.DataFrame({
    'Actual': y_test.values[:10],
    'Predicted': y_pred[:10]
})

print(result_df)
# Out:
# 예측 완료
#
# [ 159.70520227 1497.99387738  647.01869002  254.25023926 1782.33334449]
#
#    Actual    Predicted
# 0      20   159.705202
# 1    1528  1497.993877
# 2     547   647.018690
# 3     342   254.250239
# 4    1642  1782.333344
# 5      97   225.207233
# 6     930  1068.874716
# 7     725  1161.902981
# 8      18    16.750211
# 9     689   735.626448

# %% [markdown]
# # 11. 모델 성능 평가
#
# - MAE : 평균 오차 크기
# - RMSE : 큰 오차까지 고려한 평균 오차
# - R² Score : 모델 설명력

# %%
mae = mean_absolute_error(
    y_test,
    y_pred
)

mse = mean_squared_error(
    y_test,
    y_pred
)

rmse = mse ** 0.5

r2 = r2_score(
    y_test,
    y_pred
)

print('모델 성능 평가')

print()

print(f"MAE: {mae:.2f}")

print(f"MSE: {mse:.2f}")

print(f"RMSE: {rmse:.2f}")

print(f"R2 Score: {r2:.4f}")
# Out:
# 모델 성능 평가
#
# MAE: 200.13
# MSE: 123274.96
# RMSE: 351.11
# R2 Score: 0.9561

# %% [markdown]
# # 12. 실제값과 예측값 시각화
#
# 실제 값과 모델의 예측값을 비교하여
# 예측 성능을 시각적으로 확인

# %%
plt.figure(figsize=(15,5))

sample_size = 100

actual = y_test[:sample_size].values
predicted = y_pred[:sample_size]

plt.plot(
    actual,
    marker='o',
    linewidth=2,
    label='Actual'
)

plt.plot(
    predicted,
    linestyle='--',
    marker='x',
    linewidth=2,
    label='Predicted'
)

plt.title('Actual vs Predicted Passengers')

plt.xlabel('Sample')

plt.ylabel('Passengers')

plt.legend()

plt.grid()

plt.show()

# %% [markdown]
# # 13. 산점도를 이용한 예측 성능 시각화

# %%
sample_size = 5000

plt.figure(figsize=(8,8))

plt.scatter(
    y_test[:sample_size],
    y_pred[:sample_size],
    alpha=0.3
)

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    linestyle='--',
    linewidth=2
)

plt.xlabel('Actual Passengers')

plt.ylabel('Predicted Passengers')

plt.title('Actual vs Predicted Scatter Plot')

plt.grid()

plt.show()

# %% [markdown]
# # 14. Feature Importance 분석
#
# RandomForest 모델이 어떤 feature를 중요하게 사용했는지 분석
#
# Feature Importance를 통해:
# - 어떤 요소가 예측에 큰 영향을 주는지
# - 모델이 어떤 패턴을 중요하게 판단했는지
#
# 확인할 수 있습니다.

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"

font_prop = fm.FontProperties(fname=font_path)

# %%
plt.figure(figsize=(12, 8))

bars = plt.barh(
    top20['feature'],
    top20['importance']
)

for bar in bars:
    width = bar.get_width()

    plt.text(
        width + 0.002,
        bar.get_y() + bar.get_height()/2,
        f'{width:.3f}',
        va='center'
    )

plt.title(
    '상위 20개 변수 중요도',
    fontproperties=font_prop,
    fontsize=15,
    pad=15
)

plt.xlabel(
    '중요도',
    fontproperties=font_prop
)

plt.ylabel(
    '변수',
    fontproperties=font_prop
)

# y축 항목에도 폰트 적용
for label in plt.gca().get_yticklabels():
    label.set_fontproperties(font_prop)

plt.gca().invert_yaxis()

plt.grid(
    axis='x',
    linestyle='--',
    alpha=0.5
)

plt.tight_layout()

plt.show()

# %% [markdown]
# # 15. 모델 저장

# %%
import joblib

# 모델 저장
joblib.dump(
    model,
    'randomforest_boarding_model.pkl'
)

# 컬럼 저장
joblib.dump(
    X_encoded.columns,
    'model_columns.pkl'
)

# 최적 파라미터 저장
joblib.dump(
    best_params,
    'best_params.pkl'
)

# Feature Importance 저장
importance_df.to_csv(
    'feature_importance.csv',
    index=False
)

print('모델 및 관련 파일 저장 완료')
# Out:
# 모델 및 관련 파일 저장 완료

# %% [markdown]
# Streamit에서 불러오는 코드

# %%
import joblib

# 모델 불러오기
model = joblib.load(
    'randomforest_boarding_model.pkl'
)

# 컬럼 불러오기
model_columns = joblib.load(
    'model_columns.pkl'
)

print('모델 및 컬럼 불러오기 완료')
# Out:
# 모델 및 컬럼 불러오기 완료

# %% [markdown]
# # 16. 예측 오차 TOP10 분석
#
# - 예측 오차가 가장 큰 데이터 TOP10 추출
# - 실제값과 예측값 비교
# - 오차가 발생한 날짜 및 역 확인
#
# 을 통해 모델이 어떤 상황에서 예측에 실패하는지 분석

# %%
# 원본 데이터 기준으로 다시 분할

X_original = df[['날짜', '역명', '시간', '요일', '월',
                 '공휴일여부', '기온', '강수량', '적설']]

X_train_org, X_test_org, _, _ = train_test_split(
    X_original,
    y,
    test_size=0.2,
    random_state=42
)

# 오차 계산
errors = abs(y_test.values - y_pred)

# 오차 TOP10
top10_idx = np.argsort(errors)[-10:]

print("=" * 100)
print("오차 TOP10 상세 정보")
print("=" * 100)

for rank, idx in enumerate(reversed(top10_idx), start=1):

    print(f"\n순위 : {rank}")
    print(f"날짜 : {X_test_org.iloc[idx]['날짜']}")
    print(f"역명 : {X_test_org.iloc[idx]['역명']}")
    print(f"시간 : {X_test_org.iloc[idx]['시간']}")
    print(f"요일 : {X_test_org.iloc[idx]['요일']}")
    print(f"월 : {X_test_org.iloc[idx]['월']}")

    print(f"실제값 : {y_test.values[idx]:.0f}")
    print(f"예측값 : {y_pred[idx]:.0f}")
    print(f"오차 : {errors[idx]:.0f}")

    print("-" * 50)
# Out:
# ====================================================================================================
# 오차 TOP10 상세 정보
# ====================================================================================================
#
# 순위 : 1
# 날짜 : 2023-04-30
# 역명 : 종합운동장
# 시간 : 21
# 요일 : 6
# 월 : 4
# 실제값 : 14150
# 예측값 : 615
# 오차 : 13535
# --------------------------------------------------
#
# 순위 : 2
# 날짜 : 2024-10-11
# 역명 : 종합운동장
# 시간 : 21
# 요일 : 4
# 월 : 10
# 실제값 : 13274
# 예측값 : 1689
# 오차 : 11585
# --------------------------------------------------
#
# 순위 : 3
# 날짜 : 2023-05-01
# 역명 : 선릉
# 시간 : 18
# 요일 : 0
# 월 : 5
# 실제값 : 2370
# 예측값 : 13695
# 오차 : 11325
# --------------------------------------------------
#
# 순위 : 4
# 날짜 : 2024-10-17
# 역명 : 종합운동장
# 시간 : 21
# 요일 : 3
# 월 : 10
# 실제값 : 12444
# 예측값 : 1788
# 오차 : 10656
# --------------------------------------------------
#
# 순위 : 5
# 날짜 : 2024-10-19
# 역명 : 종합운동장
# 시간 : 17
# 요일 : 5
# 월 : 10
# 실제값 : 11290
# 예측값 : 1016
# 오차 : 10274
# --------------------------------------------------
#
# 순위 : 6
# 날짜 : 2024-04-10
# 역명 : 종합운동장
# 시간 : 17
# 요일 : 2
# 월 : 4
# 실제값 : 10730
# 예측값 : 1171
# 오차 : 9559
# --------------------------------------------------
#
# 순위 : 7
# 날짜 : 2024-05-19
# 역명 : 종합운동장
# 시간 : 18
# 요일 : 6
# 월 : 5
# 실제값 : 9608
# 예측값 : 649
# 오차 : 8959
# --------------------------------------------------
#
# 순위 : 8
# 날짜 : 2024-05-01
# 역명 : 종합운동장
# 시간 : 21
# 요일 : 2
# 월 : 5
# 실제값 : 11847
# 예측값 : 2949
# 오차 : 8898
# --------------------------------------------------
#
# 순위 : 9
# 날짜 : 2023-04-02
# 역명 : 종합운동장
# 시간 : 17
# 요일 : 6
# 월 : 4
# 실제값 : 9435
# 예측값 : 649
# 오차 : 8786
# --------------------------------------------------
#
# 순위 : 10
# 날짜 : 2024-06-06
# 역명 : 종합운동장
# 시간 : 20
# 요일 : 3
# 월 : 6
# 실제값 : 9461
# 예측값 : 980
# 오차 : 8481
# --------------------------------------------------

# %% [markdown]
# # 17. 특이 사례 분석 - 선릉역
#
# 오차 TOP10 분석 결과,
# 2023-05-01 선릉역 18시 데이터에서 매우 큰 과대예측이 발생
#
# 예측값은 약 13,695명이었으나
# 실제 승차인원은 2,370
#
# 해당 사례가 일반적인 패턴인지 확인하기 위해
# 같은 조건의 선릉역 데이터를 추가 분석

# %%
df[
    (df['역명'] == '선릉') &
    (df['날짜'].str.contains('2023-05'))
][['날짜', '시간', '승차인원']].sort_values(
    by='승차인원',
    ascending=False
).head(20)
# Out:
#                 날짜  시간   승차인원
# 481519  2023-05-08  18  13845
# 481619  2023-05-10  18  13774
# 481869  2023-05-15  18  13743
# 482219  2023-05-22  18  13597
# 481919  2023-05-16  18  13588
# 482269  2023-05-23  18  13573
# 482619  2023-05-30  18  13569
# 481569  2023-05-09  18  13549
# 481219  2023-05-02  18  13453
# 481969  2023-05-17  18  13408
# 481669  2023-05-11  18  13371
# 481269  2023-05-03  18  13354
# 481319  2023-05-04  18  13310
# 482319  2023-05-24  18  13292
# 482369  2023-05-25  18  13189
# 482669  2023-05-31  18  13155
# 482019  2023-05-18  18  13052
# 481719  2023-05-12  18  12979
# 482069  2023-05-19  18  12834
# 482419  2023-05-26  18  12058

# %%
df[
    (df['역명'] == '선릉') &
    (df['날짜'].str.contains('2023-05'))
][['날짜', '시간', '승차인원']].sort_values(
    by='승차인원',
    ascending=False
).head(20)
# Out:
#                 날짜  시간   승차인원
# 481519  2023-05-08  18  13845
# 481619  2023-05-10  18  13774
# 481869  2023-05-15  18  13743
# 482219  2023-05-22  18  13597
# 481919  2023-05-16  18  13588
# 482269  2023-05-23  18  13573
# 482619  2023-05-30  18  13569
# 481569  2023-05-09  18  13549
# 481219  2023-05-02  18  13453
# 481969  2023-05-17  18  13408
# 481669  2023-05-11  18  13371
# 481269  2023-05-03  18  13354
# 481319  2023-05-04  18  13310
# 482319  2023-05-24  18  13292
# 482369  2023-05-25  18  13189
# 482669  2023-05-31  18  13155
# 482019  2023-05-18  18  13052
# 481719  2023-05-12  18  12979
# 482069  2023-05-19  18  12834
# 482419  2023-05-26  18  12058

# %% [markdown]
# ## 17-1. 2023-05-01 상세 분석
#
# 오차가 크게 발생한
# 2023-05-01 18시 선릉역 데이터를 확인
#
# 해당 데이터의 시간, 날씨, 공휴일 여부 등을 분석하여
# 예측 오차의 원인을 파악

# %%
target = df[
    (df['날짜'] == '2023-05-01') &
    (df['역명'] == '선릉') &
    (df['시간'] == 18)
]

print(target.T)
# Out:
#            481169
# 날짜     2023-05-01
# 역명             선릉
# 호선            2호선
# 승차인원         2370
# 시간             18
# 하차인원         1263
# 요일              0
# 월               5
# 공휴일여부           0
# 기온           19.1
# 강수량           0.0
# 적설            0.0

# %% [markdown]
# ## 17-2. 근로자의 날 데이터 검증
#
# 2024년 근로자의 날 데이터와 비교하여
# 동일한 현상이 반복되는지 확인
#
# 이를 통해 단순 이상치인지,
# 특수 휴일 효과인지 분석

# %%
df[
    (df['날짜'] == '2024-05-01') &
    (df['역명'] == '선릉') &
    (df['시간'] == 18)
][['날짜','역명','승차인원','공휴일여부']]
# Out:
#                 날짜  역명  승차인원  공휴일여부
# 499469  2024-05-01  선릉  2300      0

# %% [markdown]
# # 18. 오차 원인 분석 및 개선 방향
#
# 오차 분석 결과
#
# 1. 종합운동장역
#    - 프로야구 경기
#    - 콘서트 및 대규모 행사
#    - 행사 종료 후 귀가 인파
#
#    등의 외부 이벤트가 존재하였으나
#    현재 모델에는 관련 정보가 포함되지 않았습니다.
#
# 2. 선릉역
#    - 2023-05-01
#    - 2024-05-01
#
#    모두 승차인원이 급감하였으나
#    공휴일여부는 0으로 기록되어 있었습니다.
#
#    이는 근로자의 날 정보가 변수에 반영되지 않은 사례로 판단됩니다.
#
# 따라서 향후 모델 개선을 위해서는
#
# - 야구 경기 일정
# - 콘서트 및 행사 일정
# - 근로자의 날
# - 대체공휴일
# - 임시공휴일
#
# 등의 추가 변수를 활용할 수 있습니다.
